# %% [markdown]
# <a href="https://colab.research.google.com/github/Edison-4/POO_Practica/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Estudiante:
    def __init__(self, nombre, apellido, cedula, email, semestre, materias=None):
        self.__nombre = nombre
        self.__apellido = apellido
        self.__cedula = cedula
        self.__email = email
        self.__semestre = semestre
        self.__materias = materias if materias is not None else []

    @property
    def nombre(self):
        return self.__nombre

    @nombre.setter
    def nombre(self, nuevo_nombre):
        self.__nombre = nuevo_nombre

    @property
    def apellido(self):
        return self.__apellido

    @apellido.setter
    def apellido(self, nuevo_apellido):
        self.__apellido = nuevo_apellido

    @property
    def cedula(self):
        return self.__cedula

    @cedula.setter
    def cedula(self, nueva_cedula):
        self.__cedula = nueva_cedula

    @property
    def email(self):
        return self.__email

    @email.setter
    def email(self, nuevo_email):
        self.__email = nuevo_email

    @property
    def semestre(self):
        return self.__semestre

    @semestre.setter
    def semestre(self, nuevo_semestre):
        self.__semestre = nuevo_semestre

    @property
    def materias(self):
        return self.__materias

    @materias.setter
    def materias(self, nuevas_materias):
        self.__materias = nuevas_materias

    def agregar_materia(self, nueva_materia):
        self.__materias.append(nueva_materia)

    def mostrar_informacion(self):
        print(f"Estudiante: {self.__nombre} {self.__apellido}")
        print(f"Cédula: {self.__cedula} | Email: {self.__email}")
        print(f"Semestre: {self.__semestre}")
        print(f"Materias: {', '.join(self.__materias) if self.__materias else 'Ninguna'}")

if __name__ == "__main__":
    estudiante1 = Estudiante(
        nombre="Carlos",
        apellido="López",
        cedula="0912345678",
        email="carlos.lopez@email.com",
        semestre=3,
        materias=["Algoritmos", "Física"]
    )

    print(f"El nombre original es: {estudiante1.nombre}")

    estudiante1.semestre = 4
    estudiante1.agregar_materia("Bases de Datos")

    print("\n--- Información Actualizada ---")
    estudiante1.mostrar_informacion()
# Out:
# El nombre original es: Carlos
#
# --- Información Actualizada ---
# Estudiante: Carlos López
# Cédula: 0912345678 | Email: carlos.lopez@email.com
# Semestre: 4
# Materias: Algoritmos, Física, Bases de Datos
